# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pandas as pd

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
plt.hist(x, bins=None, range=None, density=False,
                               weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', 
                               orientation='vertical', rwidth=None, log=False, color=None, label=None,
                               stacked=False)
# Out:
# (array([ 3.,  8., 14., 47., 43., 45., 46., 27., 11.,  6.]),
#  array([143.71319799, 148.86873721, 154.02427642, 159.17981564,
#         164.33535486, 169.49089407, 174.64643329, 179.80197251,
#         184.95751172, 190.11305094, 195.26859015]),
#  <BarContainer object of 10 artists>)

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
#n_bins = 10     #no of bins 
#patches is the specifics of histogram diagram measurements
bin_heights, bins, patches = plt.hist(x, facecolor='green')
plt.show()

# %%
bin_heights
# Out:
# array([6., 4., 2., 5., 2., 0., 0., 1., 0., 1.])

# %%
bins
# Out:
# array([  4. ,  13.6,  23.2,  32.8,  42.4,  52. ,  61.6,  71.2,  80.8,
#         90.4, 100. ])

# %%
print(patches[0])
# Out:
# Rectangle(xy=(4, 0), width=9.6, height=6, angle=0)

# %%
#to create unequally sized bins

n_bins = [10, 30, 40, 50,80,90]     #bin values
bin_heights, bins, patches = plt.hist(x, n_bins, facecolor='red')
plt.show()

# %%
#cumulative histogram -> sets the bin height as, plotted_bin(n) = actual_bin(n) + plotted_bin(n-1) for all bins
plt.hist(x, cumulative=True, facecolor='red')
plt.show()

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
#n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %%
# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)

# add a 'best fit' line
y = scipy.stats.norm.pdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
n
# Out:
# array([7.000e+00, 1.900e+01, 4.800e+01, 1.480e+02, 3.210e+02, 6.710e+02,
#        8.830e+02, 1.359e+03, 1.625e+03, 1.540e+03, 1.348e+03, 9.720e+02,
#        5.600e+02, 2.840e+02, 1.350e+02, 5.600e+01, 2.000e+01, 2.000e+00,
#        1.000e+00, 1.000e+00])

# %%
df = pd.DataFrame(
    np.random.randint(1, 7, 6000),
    columns = ['one'])

# %%
df
# Out:
#       one
# 0       6
# 1       3
# 2       3
# 3       1
# 4       4
# ...   ...
# 5995    3
# 5996    5
# 5997    4
# 5998    4
# 5999    3
#
# [6000 rows x 1 columns]

# %%
# %matplotlib inline
ax = df.plot.hist(bins=12, alpha=0.5)

# %%
df['two'] = df['one'] + np.random.randint(1, 7, 6000)
ax = df.plot.hist(bins=12, alpha=0.5)
9
# Out:
# 9
