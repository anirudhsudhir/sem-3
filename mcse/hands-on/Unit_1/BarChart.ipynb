# %%
import matplotlib.pyplot as plt
import numpy as np

#Vertical Bar Graph
x = [1, 2, 3, 4]
height = [2, 4, 5 , 3]
labels = ['cars', 'bikes', 'bicycles', 'pedestrians']
y = np.arange(0.2,100)
plt.bar(x, height, align='center')
plt.xticks(x, labels)    #optional to set the class names for the bars
plt.yticks(height)     #optional to set the values of y axis
plt.show()

# %%
#Horizontal Bar Graph
x = [1, 2, 3, 4]
height = [2, 4, 5 , 3]
labels = ['cars', 'bikes', 'bicycles', 'pedestrians']
y = np.arange(0.2, 100)
plt.barh(x, height, align='center')
plt.yticks(x, labels)    #optional to set the class names for the bars
plt.xticks(height)     #optional to set the values of y axis
plt.show()

# %%
#edge aligned bar charts
plt.bar(x, height, align='edge')
plt.xticks(x, labels)    
plt.show()

# %%
#setting the colours of the bars
plt.bar(x, height, color='black')
plt.xticks(x, labels)    
plt.show()

# %%
#stacked bar chart
x = [1, 2, 3, 4]
men = [4, 3, 8, 5]
women = [2, 5, 9, 10]
labels = ['athletics', 'aquatics', 'hockey', 'tennis']
p1 = plt.bar(x, men)
p2 = plt.bar(x, women, bottom=men)
plt.xticks(x, labels)
plt.legend((p1[0], p2[0]), ('Men', 'Women'))
plt.show()

# %%
#Grouped Bar Chart
x = [1, 2, 3, 4]
men = [4, 3, 8, 5]
women = [2, 5, 9, 10]
labels = ['athletics', 'aquatics', 'hockey', 'tennis']

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index,men, bar_width,
alpha=opacity,
color='b',
label='Men')

rects2 = plt.bar(index + bar_width, women, bar_width,
alpha=opacity,
color='g',
label='Women')

plt.xlabel('Sports')
plt.ylabel('Count')
plt.title('Count by sport')
plt.xticks(index + bar_width, labels)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7 # create plot
#       8 fig, ax = plt.subplots()
# ----> 9 index = np.arange(n_groups)
#      10 bar_width = 0.35
#      11 opacity = 0.8
#
# NameError: name 'n_groups' is not defined

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(5)
y1 = [34, 56, 12, 89, 67]
y2 = [12, 56, 78, 45, 90]
width = 0.40
  
# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width)
plt.bar(x+0.2, y2, width)
plt.legend()
plt.show()
# Out:
# /var/folders/_b/7k_xhq8s36qdft_gbspxy7mm0000gp/T/ipykernel_27482/149378528.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = np.arange(5)
print(x)
y1 = [34, 56, 12, 89, 67]
y2 = [12, 56, 78, 45, 90]
y3 = [14, 23, 45, 25, 89]
width = 0.2
  
# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width, color='cyan')
plt.bar(x, y2, width, color='orange')
plt.bar(x+0.2, y3, width, color='green')
plt.xticks(x, ['Team A', 'Team B', 'Team C', 'Team D', 'Team E'])
plt.xlabel("Teams")
plt.ylabel("Scores")
plt.legend(["Round 1", "Round 2", "Round 3"])
plt.show()
# Out:
# [0 1 2 3 4]
